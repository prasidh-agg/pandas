# %% [markdown]
# Series

# %% [markdown]
# ## %config Completer.use_jedi = False

# %%
import pandas as pd
import numpy as np

# %%
sports=["cricket","football","baseball","soccer"]
pd.Series(sports)
numbers =[1,2,3,4,5,6,7]
pd.Series(numbers)
booleans=[True, False, True]
pd.Series(booleans)
websters={"banana": "A fruit","cricket": "A sport"}
pd.Series(websters)
# Out:
# banana     A fruit
# cricket    A sport
# dtype: object
